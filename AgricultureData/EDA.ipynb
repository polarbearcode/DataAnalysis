# %%
import pandas as pd
import os

# %%
pathToData = os.path.join(os.getcwd(), "Data", "Production_Crops_Livestock_E_All_Data.csv")

# %%
agData = pd.read_csv(pathToData, encoding="latin-1")
agData.head()
# Out:
#    Area Code         Area  Item Code                              Item  \
# 0          2  Afghanistan        221               Almonds, with shell
# 1          2  Afghanistan        221               Almonds, with shell
# 2          2  Afghanistan        221               Almonds, with shell
# 3          2  Afghanistan        711  Anise, badian, fennel, coriander
# 4          2  Afghanistan        711  Anise, badian, fennel, coriander
#
#    Element Code         Element    Unit  Y1961 Y1961F  Y1962  ...    Y2016  \
# 0          5312  Area harvested      ha    NaN    NaN    NaN  ...  19481.0
# 1          5419           Yield   hg/ha    NaN    NaN    NaN  ...  16859.0
# 2          5510      Production  tonnes    NaN    NaN    NaN  ...  32843.0
# 3          5312  Area harvested      ha    NaN      M    NaN  ...  24500.0
# 4          5419           Yield   hg/ha    NaN    NaN    NaN  ...   7075.0
#
#    Y2016F    Y2017  Y2017F    Y2018  Y2018F    Y2019  Y2019F    Y2020  Y2020F
# ...

# %%
agData["Area"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belgium-Luxembourg', 'Belize',
#        'Benin', 'Bhutan', 'Bolivia (Plurinational State of)',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada',
#        'Central African Republic', 'Chad', 'Chile', 'China',
#        'China, Hong Kong SAR', 'China, Macao SAR', 'China, mainland',
#        'China, Taiwan Province of', 'Colombia', 'Comoros', 'Congo',
#        'Cook Islands', 'Costa Rica', "Côte d'Ivoire", 'Croatia', 'Cuba',
#        'Cyprus', 'Czechia', 'Czechoslovakia',
#        "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
agDataChina = agData[agData["Area"] == "China, mainland"]
agDataChina.head()
# Out:
#        Area Code             Area  Item Code  \
# 10685         41  China, mainland        221
# 10686         41  China, mainland        221
# 10687         41  China, mainland        221
# 10688         41  China, mainland        711
# 10689         41  China, mainland        711
#
#                                    Item  Element Code         Element    Unit  \
# 10685               Almonds, with shell          5312  Area harvested      ha
# 10686               Almonds, with shell          5419           Yield   hg/ha
# 10687               Almonds, with shell          5510      Production  tonnes
# 10688  Anise, badian, fennel, coriander          5312  Area harvested      ha
# 10689  Anise, badian, fennel, coriander          5419           Yield   hg/ha
#
#         Y1961 Y1961F   Y1962  ...    Y2016  Y2016F    Y2017  Y2017F    Y2018  \
# 10685     NaN      M     NaN  ...  13194.0      Im  12853.0      Im  12522.0
# ...

# %%
agDataChina["Item"].unique()
# Out:
# array(['Almonds, with shell', 'Anise, badian, fennel, coriander',
#        'Apples', 'Apricots', 'Artichokes', 'Asparagus', 'Asses',
#        'Avocados', 'Bananas', 'Barley', 'Bastfibres, other', 'Beans, dry',
#        'Beans, green', 'Beehives', 'Beer of barley', 'Beeswax',
#        'Berries nes', 'Broad beans, horse beans, dry', 'Buckwheat',
#        'Buffaloes', 'Butter, buffalo milk', 'Butter, cow milk',
#        'Cabbages and other brassicas', 'Camels', 'Carrots and turnips',
#        'Cashew nuts, with shell', 'Cassava', 'Castor oil seed', 'Cattle',
#        'Cauliflowers and broccoli', 'Cereals nes', 'Cheese, buffalo milk',
#        'Cheese, goat milk', 'Cheese, sheep milk',
#        'Cheese, skimmed cow milk', 'Cheese, whole cow milk', 'Cherries',
#        'Chestnut', 'Chick peas', 'Chickens', 'Chillies and peppers, dry',
#        'Chillies and peppers, green', 'Cinnamon (cannella)', 'Cloves',
#        'Coconuts', 'Coffee, green', 'Cotton lint', 'Cottonseed',
# ...

# %%
agDataChinaKiwi = agDataChina[agDataChina["Item"] == "Kiwi fruit"]
agDataChinaKiwi.head()
# Out:
#        Area Code             Area  Item Code        Item  Element Code  \
# 10892         41  China, mainland        592  Kiwi fruit          5312
# 10893         41  China, mainland        592  Kiwi fruit          5419
# 10894         41  China, mainland        592  Kiwi fruit          5510
#
#               Element    Unit  Y1961 Y1961F  Y1962  ...      Y2016  Y2016F  \
# 10892  Area harvested      ha    NaN      M    NaN  ...   172845.0      Im
# 10893           Yield   hg/ha    NaN    NaN    NaN  ...   122424.0      Fc
# 10894      Production  tonnes    NaN      M    NaN  ...  2116031.0      Im
#
#            Y2017  Y2017F      Y2018  Y2018F      Y2019  Y2019F      Y2020  \
# 10892   174742.0      Im   174953.0     NaN   182566.0     NaN   184554.0
# 10893   121959.0      Fc   120831.0      Fc   120325.0      Fc   120835.0
# 10894  2131141.0      Im  2113971.0     NaN  2196727.0     NaN  2230065.0
#
#        Y2020F
# 10892      Im
# 10893      Fc
# 10894      Im
#
# ...

# %%
selectCols = ["Element", "Unit"]
for x in range(2000, 2021):
    selectCols.append("Y" + str(x))
agDataChinaKiwi = agDataChinaKiwi[selectCols]
agDataChinaKiwi.head()
# Out:
#               Element    Unit     Y2000     Y2001      Y2002      Y2003  \
# 10892  Area harvested      ha   70000.0   75000.0    78000.0    80000.0
# 10893           Yield   hg/ha  121429.0  126667.0   128205.0   131250.0
# 10894      Production  tonnes  850000.0  950000.0  1000000.0  1050000.0
#
#            Y2004      Y2005      Y2006      Y2007  ...      Y2011      Y2012  \
# 10892    83000.0    85000.0    87000.0    90000.0  ...   100000.0   110000.0
# 10893   132530.0   129412.0   132184.0   133333.0  ...   125537.0   132070.0
# 10894  1100000.0  1100000.0  1150000.0  1200000.0  ...  1255374.0  1452767.0
#
#            Y2013      Y2014      Y2015      Y2016      Y2017      Y2018  \
# 10892   161500.0   145000.0   181900.0   172845.0   174742.0   174953.0
# 10893   109340.0   126897.0   120279.0   122424.0   121959.0   120831.0
# 10894  1765847.0  1840000.0  2187867.0  2116031.0  2131141.0  2113971.0
#
#            Y2019      Y2020
# 10892   182566.0   184554.0
# ...

# %%
agData = pd.read_csv(pathToData, encoding="latin-1")
def cropData(df, agItem):
    """
        Filter the data for a specific crop/food. 
        Argument:
            df: the dataframe
            agItem: String, the crop/food to filter for. 
        Return: the agriculture data filtered by the crop/food.     
    """
    return df[df["Item"] == agItem]

def getYearData(df, year1, year2):
    """
        Get the year columns between year1 and year2
        Arguments:
            df: the dataframe
            year1: integer, the beginning year column
            year2: integer, the ending year column
        Return: the ag data with the year columns only    
    """
    getCols = ["Area", "Item", "Element"]
    for y in range(year1, year2 + 1):
        getCols.append("Y" + str(y))
    
    return df[getCols]

# %%
agDataKiwi = cropData(agData, "Kiwi fruit")
agDataKiwi = getYearData(agDataKiwi, 2015, 2020)
agDataKiwi.head()
# Out:
#            Area        Item         Element     Y2015     Y2016     Y2017  \
# 2113  Australia  Kiwi fruit  Area harvested     174.0     129.0     127.0
# 2114  Australia  Kiwi fruit           Yield  155057.0  161395.0  164173.0
# 2115  Australia  Kiwi fruit      Production    2698.0    2082.0    2085.0
# 4363    Belgium  Kiwi fruit  Area harvested       NaN       NaN       NaN
# 4364    Belgium  Kiwi fruit      Production       NaN       NaN       NaN
#
#          Y2018     Y2019     Y2020
# 2113     177.0     172.0     168.0
# 2114  154633.0  151686.0  150833.0
# 2115    2737.0    2609.0    2534.0
# 4363       0.0       0.0       0.0
# 4364       0.0       0.0       0.0

# %%
agData = pd.read_csv(pathToData, encoding="latin-1")
agData[(agData["Element"] == "Yield") & (agData["Item"] == "Apples") & (agData["Area"].isin(["China", "Brazil"]))]
# Out:
#       Area Code    Area  Item Code    Item  Element Code Element   Unit  \
# 6508         21  Brazil        515  Apples          5419   Yield  hg/ha
# 9855        351   China        515  Apples          5419   Yield  hg/ha
#
#         Y1961 Y1961F    Y1962  ...     Y2016  Y2016F     Y2017  Y2017F  \
# 6508  95193.0     Fc  96211.0  ...  308465.0      Fc  392355.0      Fc
# 9855      NaN    NaN      NaN  ...  190317.0      Fc  212575.0      Fc
#
#          Y2018  Y2018F     Y2019  Y2019F     Y2020  Y2020F
# 6508  362035.0      Fc  377395.0      Fc  302836.0      Fc
# 9855  202371.0      Fc  207832.0      Fc  211842.0      Fc
#
# [2 rows x 127 columns]

# %%
agDataTest = agData[(agData['Area'].isin(["Brazil", "China, mainland", "India", "Indonesia", "Australia"])) & (agData['Item'] == "Oranges")]
agDataTest = agDataTest[["Area", "Element", "Unit", "Y2019", "Y2020"]]
agDataTest.head(20)
# Out:
#                   Area         Element    Unit       Y2019       Y2020
# 2222         Australia  Area harvested      ha     17590.0     19659.0
# 2223         Australia           Yield   hg/ha    195013.0    194812.0
# 2224         Australia      Production  tonnes    343028.0    382980.0
# 6716            Brazil  Area harvested      ha    589764.0    572698.0
# 6717            Brazil           Yield   hg/ha    289783.0    291740.0
# 6718            Brazil      Production  tonnes  17090362.0  16707897.0
# 11037  China, mainland  Area harvested      ha    417546.0    388554.0
# 11038  China, mainland           Yield   hg/ha    185910.0    193023.0
# 11039  China, mainland      Production  tonnes   7762604.0   7500000.0
# 24998            India  Area harvested      ha    656000.0    670000.0
# 24999            India           Yield   hg/ha    144954.0    147075.0
# 25000            India      Production  tonnes   9509000.0   9854000.0
# ...

# %%
(agDataTest.iat[8, 3] + agDataTest.iat[11, 3]) * 10000 / (agDataTest.iat[6, 3] + agDataTest.iat[9, 3])
# Out:
# 160883.68826300875

# %%
(agDataTest.iat[8, 4] + agDataTest.iat[11, 4]) * 10000 / (agDataTest.iat[6, 4] + agDataTest.iat[9, 4])
# Out:
# 163940.6208847163
